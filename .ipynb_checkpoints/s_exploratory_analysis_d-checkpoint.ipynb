# %% [markdown]
# # Check the correlations between the variables and start with a general data exploratory

# %% [markdown]
# First import the necessary datasets and read the file(s)

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

from sklearn.linear_model import LinearRegression

# ignore warnings
import warnings
warnings.filterwarnings(action='ignore', category=RuntimeWarning)

# %%
df = pd.read_csv('day.csv', index_col=0)
df.head()
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1        0        6           0
# 2        2011-01-02       1   0     1        0        0           0
# 3        2011-01-03       1   0     1        0        1           1
# 4        2011-01-04       1   0     1        0        2           1
# 5        2011-01-05       1   0     1        0        3           1
#
#          weathersit      temp     atemp       hum  windspeed  casual  \
# instant
# 1                 2  0.344167  0.363625  0.805833   0.160446     331
# 2                 2  0.363478  0.353739  0.696087   0.248539     131
# 3                 1  0.196364  0.189405  0.437273   0.248309     120
# 4                 1  0.200000  0.212122  0.590435   0.160296     108
# 5                 1  0.226957  0.229270  0.436957   0.186900      82
#
#          registered   cnt
# instant
# 1               654   985
# 2               670   801
# 3              1229  1349
# 4              1454  1562
# 5              1518  1600

# %%
df.casual.sum(), df.registered.sum(), df.casual.sum()/df.cnt.sum()
# Out:
# (620017, 2672662, 0.18830168382645257)

# %% [markdown]
# #### Dive into some exploratory data analysis

# %%
# check for empty values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 731 entries, 1 to 731
# Data columns (total 15 columns):
# dteday        731 non-null object
# season        731 non-null int64
# yr            731 non-null int64
# mnth          731 non-null int64
# holiday       731 non-null int64
# weekday       731 non-null int64
# workingday    731 non-null int64
# weathersit    731 non-null int64
# temp          731 non-null float64
# atemp         731 non-null float64
# hum           731 non-null float64
# windspeed     731 non-null float64
# casual        731 non-null int64
# registered    731 non-null int64
# cnt           731 non-null int64
# dtypes: float64(4), int64(10), object(1)
# memory usage: 91.4+ KB

# %% [markdown]
# * there seem to be no null values
# * the datetype of dteday is string, all other variables are either integers or floats

# %%
df['dteday'] = pd.to_datetime(df['dteday'])
df['dteday'].describe()
# Out:
# count                     731
# unique                    731
# top       2012-02-14 00:00:00
# freq                        1
# first     2011-01-01 00:00:00
# last      2012-12-31 00:00:00
# Name: dteday, dtype: object

# %%
df.shape
# Out:
# (731, 15)

# %%
df.describe()
# Out:
#            season          yr        mnth     holiday     weekday  workingday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     2.496580    0.500684    6.519836    0.028728    2.997264    0.683995
# std      1.110807    0.500342    3.451913    0.167155    2.004787    0.465233
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%      3.000000    1.000000    7.000000    0.000000    3.000000    1.000000
# 75%      3.000000    1.000000   10.000000    0.000000    5.000000    1.000000
# max      4.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.544894    0.183051    0.162961    0.142429    0.077498
# min      1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      2.000000    0.655417    0.608602    0.730209    0.233214
# max      3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000

# %%
# look at the development of rentals over the years
df.groupby('yr')['cnt'].sum().plot.bar()

# %%
# let's look at a boxplot for cnt and year
sns.boxplot(x="yr", y="cnt", data=df)

# %% [markdown]
# * The number of rentals increased heavily from year one to year two

# %%
# inspect 
sns.pairplot(df)
plt.savefig('s_pariplot_complete.png')

# %% [markdown]
# This gives us a nice overview of some relationships between variables. Interesting relationships are:
#
# * season: negative quadratic relationship
# * yr: increase
# * month: similar to season we observe a negative quadratic relationship
# * holiday: during holidays customers seem to use the bike sharing less frequently
# * weekday: the mean is pretty stable over all of the weekdays but the distribution changes slightly
# * workingday: rather the same
# * weathersit: cnt is decreasing in weathersit; the relationship might even be of the relationship 1/sqrt(x) type
# * temp: there is a relationship and it seems to be linear
# * atemp: there is a relationship and it seems to be linear
# * hum: very week relationship between humidity and cnt; statistically significant?
# * windspead: same as hum
#
# The following boxplots also helped with that.

# %% [markdown]
# What about the relationship between holidays and cnt:

# %%
# let's look at a boxplot for cnt and year
sns.boxplot(x="weathersit", y="cnt", data=df)

# %%
# let's look at a boxplot for cnt and year
sns.boxplot(x=df['workingday'], y="cnt", data=df)

# %%
sns.boxplot(x=df['weekday'], y="cnt", data=df)

# %%
# displays the month in which the holidays are
df[df['holiday'] == 1].groupby(df.dteday.dt.month)['dteday'].count()
# Out:
# dteday
# 1     3
# 2     2
# 4     2
# 5     2
# 7     2
# 9     2
# 10    2
# 11    4
# 12    2
# Name: dteday, dtype: int64

# %%
# Compute the correlation matrix
corr = df.corr()

# %%
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# %%
# Draw the heatmap with the mask and correct aspect ratio
plt.figure(figsize=(20, 20))
sns.heatmap(corr, cmap=cmap, annot=True, fmt='.1g')

# %% [markdown]
# We observe high correlations among the following input variables (casual, registered and cnt are for now considered as output variables):
#
# * season and month: I would exclude season from the model because month might catch more granular data
# * weathersit and hum: maybe only include one
# * temp and atemp: linearly dependent; just chose atemp, the feeling temperature

# %%
# plot a graph of registered and date
df.head()
# Out:
#             dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1       2011-01-01       1   0     1        0        6           0
# 2       2011-01-02       1   0     1        0        0           0
# 3       2011-01-03       1   0     1        0        1           1
# 4       2011-01-04       1   0     1        0        2           1
# 5       2011-01-05       1   0     1        0        3           1
#
#          weathersit      temp     atemp       hum  windspeed  casual  \
# instant
# 1                 2  0.344167  0.363625  0.805833   0.160446     331
# 2                 2  0.363478  0.353739  0.696087   0.248539     131
# 3                 1  0.196364  0.189405  0.437273   0.248309     120
# 4                 1  0.200000  0.212122  0.590435   0.160296     108
# 5                 1  0.226957  0.229270  0.436957   0.186900      82
#
#          registered   cnt
# instant
# 1               654   985
# 2               670   801
# 3              1229  1349
# 4              1454  1562
# 5              1518  1600

# %%
plt.figure(figsize=(20,10))
plt.plot(df['dteday'], df['registered'])
plt.plot(df['dteday'], df['casual'])
plt.plot(df['dteday'], df['cnt'])
#plt.xticks(rotation='vertical')

# %% [markdown]
# * Total rentals seem to be made up by registered rentals only in winter. In summer casual rentals kick in.

# %% [markdown]
# ## Regress on the single predictors to inspect the relationship between the predictors and the predicted value

# %%
np.array(df['hum']).reshape(1, -1)
# Out:
# array([[0.805833, 0.696087, 0.437273, 0.590435, 0.436957, 0.518261,
#         0.498696, 0.535833, 0.434167, 0.482917, 0.686364, 0.599545,
#         0.470417, 0.537826, 0.49875 , 0.48375 , 0.5375  , 0.861667,
#         0.741739, 0.538333, 0.457083, 0.4     , 0.436522, 0.491739,
#         0.616957, 0.8625  , 0.6875  , 0.793043, 0.651739, 0.722174,
#         0.60375 , 0.829565, 0.775417, 0.437826, 0.585217, 0.929167,
#         0.747083, 0.7325  , 0.697083, 0.67625 , 0.684583, 0.67    ,
#         0.492917, 0.755417, 0.549167, 0.493333, 0.487083, 0.613333,
#         0.61125 , 0.567083, 0.467917, 0.437083, 0.538333, 0.587917,
#         0.833333, 0.582083, 0.569583, 0.589583, 0.504167, 0.59875 ,
#         0.777917, 0.69    , 0.592083, 0.567917, 0.57375 , 0.534583,
#         0.479167, 0.504167, 0.373333, 0.36    , 0.4225  , 0.48875 ,
#         0.60125 , 0.51875 , 0.447083, 0.492083, 0.53875 , 0.457917,
#         0.450833, 0.492083, 0.57375 , 0.683333, 0.6675  , 0.633333,
#         0.529583, 0.485833, 0.699167, 0.717917, 0.645   , 0.505833,
#         0.577083, 0.600417, 0.844167, 0.865417, 0.7625  , 0.694167,
#         0.655   , 0.45    , 0.596667, 0.594583, 0.613333, 0.62375 ,
#         0.66875 , 0.704167, 0.6775  , 0.659583, 0.6425  , 0.613333,
#         0.6525  , 0.654167, 0.70375 , 0.672917, 0.620417, 0.715833,
#         0.732917, 0.530417, 0.545417, 0.686667, 0.619583, 0.519167,
#         0.570833, 0.603333, 0.711667, 0.734167, 0.67375 , 0.677083,
#         0.635833, 0.615   , 0.712917, 0.845833, 0.730417, 0.62    ,
#         0.552083, 0.590417, 0.5875  , 0.638333, 0.815   , 0.790833,
#         0.755   , 0.74125 , 0.810417, 0.73625 , 0.799167, 0.5475  ,
#         0.50375 , 0.52    , 0.577083, 0.637083, 0.6725  , 0.501667,
#         0.57    , 0.734583, 0.8725  , 0.536667, 0.618333, 0.66875 ,
#         0.646667, 0.467083, 0.492917, 0.57    , 0.630833, 0.690833,
#         0.69    , 0.542917, 0.583333, 0.649167, 0.871667, 0.79375 ,
#         0.722917, 0.6275  , 0.664167, 0.708333, 0.709583, 0.761667,
#         0.630833, 0.463333, 0.539167, 0.494583, 0.640417, 0.7075  ,
#         0.558333, 0.692917, 0.728333, 0.815   , 0.572917, 0.51    ,
#         0.568333, 0.641667, 0.63625 , 0.800417, 0.807083, 0.72    ,
#         0.694583, 0.88    , 0.825455, 0.666667, 0.581667, 0.522083,
#         0.49125 , 0.532917, 0.494167, 0.567083, 0.5475  , 0.333478,
#         0.540833, 0.645417, 0.659167, 0.741667, 0.662917, 0.552083,
#         0.620417, 0.524583, 0.545417, 0.692917, 0.623333, 0.685   ,
#         0.61375 , 0.580417, 0.56875 , 0.404583, 0.468333, 0.535417,
#         0.786667, 0.50625 , 0.555652, 0.649583, 0.806667, 0.823333,
#         0.7675  , 0.73375 , 0.485   , 0.50875 , 0.764167, 0.91125 ,
#         0.905417, 0.925   , 0.596667, 0.538333, 0.485833, 0.642917,
#         0.650417, 0.83875 , 0.907083, 0.66625 , 0.625417, 0.667917,
#         0.556667, 0.44125 , 0.515417, 0.791304, 0.734783, 0.823333,
#         0.652917, 0.59    , 0.752917, 0.483333, 0.5775  ]])

# %%
for x in df.iloc[0:1, 1:-3]:
    m = LinearRegression()
    m.fit(np.array(df[x]).reshape(-1, 1), df['cnt'])
    print('The score for the regression on {} is {}'.format(m.score(np.array(df[x]).reshape(-1, 1), df['cnt']))
